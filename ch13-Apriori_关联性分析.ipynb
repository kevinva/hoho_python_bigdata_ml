# %%
import pandas as pd

# %%
data = pd.DataFrame()
data['用户'] = [1, 2, 3, 4, 5, ]
data['购买商品列表'] = ['A, B, C', 'A, B', 'B, C', 'A, B, C, D', 'B, C, D']

# %%
data
# Out:
#    用户      购买商品列表
# 0   1     A, B, C
# 1   2        A, B
# 2   3        B, C
# 3   4  A, B, C, D
# 4   5     B, C, D

# %% [markdown]
# ### 一些概念
#
# ##### 事务库
#
# 如上面表格数据就是一个事务库
#
#
# ##### 事务
#
# 每一条记录就是一个事务
#
# ##### 项和项集
#
# 每条记录中，每件商品为一个“项”，如"A"；项集为商品的集合，如”A,B,C“
#
# ##### 关联规则
#
# 形如A -> B的表达式，A为前件，B为后件，表示一个用户如果购买了商品A，也会购买商品B，有时也表示为{A,B} -> {C}
#
# ##### 支持度
#
# 项集的支持度定义为包含该项集的事务在所有事务中所占的比率，如上{A,B}项集在事务1,2,4出现过，则它的支持度为3/5 = 60%
#
# ##### 频繁项集
#
# 支持度大于设定的阈值的项集
#
# ##### 置信度
#
# 关联规则X -> Y的置信度为在购买项集X的基础上购买项集Y的概率 $P(Y|X) = \frac{P(XY)}{P(X)}$，可理解为项集Y在包含项集X的事务中出现的频繁程度。
#
# ##### 强关联规则（最终目标）
#
# 在实际应用中，通常是先寻找满足最小支持度的频繁项集，然后在频繁项集中寻找满足最小置信度的关联规则，这样的关联规则称为强关联规则。

# %% [markdown]
# ### Apriori核心思想  ([əpriˈɔri])
#
# 用于快速挖掘频繁项集。如果连长度n-1的项集都不是频繁项集，那么就不用考虑长度为n的项集了。所以，先计算长度为1的项集，挖掘出其中的频繁项集；再将长度为1的频繁项集进行排列组合，挖掘其中长度为2的频繁项集；....

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (0.20.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from mlxtend) (61.2.0)
# Requirement already satisfied: scipy>=1.2.1 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from mlxtend) (1.8.1)
# Requirement already satisfied: pandas>=0.24.2 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: numpy>=1.16.2 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from mlxtend) (1.23.2)
# Requirement already satisfied: joblib>=0.13.2 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (9.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.8)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/hoho_RL/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
df = pd.read_excel('./data/病症.xlsx')

# %%
df
# Out:
#      病人编号                病人症状
# 0       1             消化不良,便秘
# 1       2               心悸,失眠
# 2       3            腰疼,脱发,眼干
# 3       4  腹胀,便秘,哮喘,胸闷气短,消化不良
# 4       5        神经衰弱,失眠,月经不调
# ..    ...                 ...
# 995   996          心悸,眼干,月经不调
# 996   997    腰疼,脱发,眼干,易怒,月经不调
# 997   998       心悸,眼干,月经不调,鼻炎
# 998   999          脱发,眼干,月经不调
# 999  1000          心悸,哮喘,月经不调
#
# [1000 rows x 2 columns]

# %%
symptoms = []

for i in df['病人症状'].tolist():
    symptoms.append(i.split(','))

# %%
symptoms
# Out:
# [['消化不良', '便秘'],
#  ['心悸', '失眠'],
#  ['腰疼', '脱发', '眼干'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['神经衰弱', '失眠', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['腰疼', '眼干', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '月经不调', '消化不良'],
#  ['消化不良', '月经不调'],
#  ['腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干', '易怒'],
#  ['失眠', '月经不调'],
#  ['哮喘', '腰疼'],
#  ['心悸', '腹胀'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['消化不良', '便秘'],
#  ['失眠', '月经不调'],
#  ['消化不良', '便秘'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['哮喘', '鼻炎', '脱发'],
#  ['心悸', '腹胀'],
#  ['心悸', '失眠', '月经不调'],
#  ['腰疼', '眼干', '便秘'],
#  ['心悸', '失眠'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['神经衰弱', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '眼干', '月经不调', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['消化不良', '月经不调'],
#  ['神经衰弱', '失眠', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['心悸', '月经不调', '胸闷气短'],
#  ['消化不良', '便秘'],
#  ['心悸', '失眠'],
#  ['心悸', '失眠', '脱发', '眼干', '胸闷气短'],
#  ['失眠', '哮喘', '鼻炎', '耳鸣耳聋'],
#  ['腰疼', '脱发', '眼干'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['神经衰弱', '消化不良'],
#  ['心悸', '失眠'],
#  ['眼干', '腰疼'],
#  ['消化不良', '腰疼', '脱发', '眼干', '易怒'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['心悸', '眼干', '易怒'],
#  ['心悸', '失眠'],
#  ['心悸', '失眠', '月经不调'],
#  ['腹胀', '便秘'],
#  ['神经衰弱', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['腰疼', '眼干', '月经不调'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '脱发', '眼干', '胸闷气短'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['消化不良', '便秘'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['失眠', '月经不调'],
#  ['眼干', '易怒'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '月经不调', '消化不良'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['失眠', '月经不调', '易怒'],
#  ['脱发', '眼干', '月经不调'],
#  ['胸闷气短', '耳鸣耳聋'],
#  ['心悸', '哮喘', '月经不调'],
#  ['心悸', '失眠'],
#  ['失眠', '月经不调'],
#  ['消化不良', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['脱发', '眼干'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['消化不良', '便秘'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '失眠', '腰疼', '眼干', '便秘'],
#  ['神经衰弱', '失眠', '便秘'],
#  ['心悸', '失眠', '眼干', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱'],
#  ['失眠', '月经不调'],
#  ['哮喘', '腰疼'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调', '易怒'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '腹胀'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['腰疼', '脱发', '月经不调', '眼干'],
#  ['神经衰弱', '失眠', '便秘'],
#  ['腹胀', '便秘'],
#  ['消化不良', '易怒'],
#  ['胸闷气短', '耳鸣耳聋'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['消化不良', '便秘'],
#  ['失眠', '月经不调', '易怒'],
#  ['心悸', '月经不调', '胸闷气短'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['胸闷气短', '耳鸣耳聋'],
#  ['腰疼', '脱发', '眼干', '易怒', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['脱发', '眼干', '月经不调'],
#  ['脱发', '眼干'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['心悸', '月经不调', '胸闷气短'],
#  ['神经衰弱', '失眠', '便秘'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良', '鼻炎'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '失眠', '腰疼', '眼干', '便秘'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良', '鼻炎'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['消化不良', '便秘'],
#  ['腰疼', '脱发', '眼干', '易怒', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '哮喘', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['神经衰弱', '失眠', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '脱发', '眼干', '胸闷气短'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['脱发', '眼干'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '眼干', '易怒'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['心悸', '腹胀'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '神经衰弱', '眼干', '月经不调', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['心悸', '哮喘', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '眼干', '消化不良'],
#  ['失眠', '月经不调'],
#  ['消化不良', '便秘'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['腰疼', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['失眠', '腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '月经不调', '消化不良'],
#  ['胸闷气短', '耳鸣耳聋'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['腰疼', '眼干', '月经不调'],
#  ['腰疼', '眼干', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '月经不调', '消化不良'],
#  ['腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '哮喘', '月经不调'],
#  ['腰疼', '脱发', '眼干', '易怒', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['消化不良', '便秘'],
#  ['腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良'],
#  ['心悸', '月经不调', '消化不良'],
#  ['失眠', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '神经衰弱'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '月经不调', '消化不良'],
#  ['消化不良', '便秘'],
#  ['腰疼', '脱发', '眼干', '易怒', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['眼干', '腰疼'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['失眠', '眼干', '月经不调'],
#  ['腰疼', '眼干', '便秘'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['失眠', '哮喘', '鼻炎', '耳鸣耳聋'],
#  ['消化不良', '腰疼', '脱发', '眼干', '易怒'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['哮喘', '腰疼'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '腰疼', '脱发', '眼干', '易怒'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['神经衰弱', '失眠', '便秘'],
#  ['神经衰弱', '眼干', '消化不良'],
#  ['心悸', '月经不调', '胸闷气短'],
#  ['腰疼', '眼干', '月经不调'],
#  ['失眠', '月经不调', '易怒'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['脱发', '眼干', '胸闷气短'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['消化不良', '便秘'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠'],
#  ['脱发', '眼干'],
#  ['腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['心悸', '眼干', '易怒'],
#  ['心悸', '月经不调', '消化不良'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '脱发', '眼干', '胸闷气短'],
#  ['心悸', '失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '月经不调'],
#  ['神经衰弱', '消化不良'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调', '胸闷气短'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['心悸', '失眠'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '眼干', '月经不调', '消化不良'],
#  ['心悸', '哮喘', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['神经衰弱', '月经不调', '消化不良'],
#  ['腰疼', '脱发', '眼干', '易怒'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['心悸', '眼干', '易怒'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '眼干', '月经不调', '消化不良'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['腰疼', '脱发', '月经不调', '眼干'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['失眠', '腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '失眠'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '腹胀'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调', '胸闷气短'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['腰疼', '眼干', '月经不调'],
#  ['腰疼', '眼干', '月经不调'],
#  ['消化不良', '眼干'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '神经衰弱'],
#  ['心悸', '失眠', '月经不调'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['失眠', '月经不调'],
#  ['脱发', '眼干', '月经不调'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['脱发', '眼干', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['哮喘', '腰疼'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['脱发', '眼干', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['腹胀', '便秘', '消化不良'],
#  ['失眠', '眼干', '月经不调'],
#  ['神经衰弱', '失眠', '月经不调'],
#  ['心悸', '哮喘', '月经不调'],
#  ['心悸', '眼干', '易怒'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['神经衰弱', '失眠', '便秘'],
#  ['失眠', '月经不调'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良', '鼻炎'],
#  ['神经衰弱', '眼干', '消化不良'],
#  ['失眠', '腰疼', '脱发', '眼干', '易怒'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['胸闷气短', '耳鸣耳聋'],
#  ['心悸', '失眠', '鼻炎', '耳鸣耳聋'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['脱发', '眼干', '胸闷气短'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良', '鼻炎'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['心悸', '神经衰弱', '眼干', '月经不调', '消化不良'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['心悸', '神经衰弱', '眼干', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['心悸', '月经不调', '消化不良'],
#  ['消化不良', '便秘'],
#  ['神经衰弱', '月经不调', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠', '月经不调', '胸闷气短'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['消化不良', '便秘'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '失眠'],
#  ['消化不良', '便秘'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良', '鼻炎'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良'],
#  ['心悸', '眼干', '易怒'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['消化不良', '便秘'],
#  ['哮喘', '鼻炎', '脱发'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['腰疼', '眼干', '月经不调'],
#  ['消化不良', '易怒'],
#  ['腰疼', '脱发', '月经不调', '眼干'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['神经衰弱', '失眠', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '腹胀'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '月经不调', '胸闷气短'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['腹胀', '便秘'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['失眠', '眼干', '月经不调'],
#  ['消化不良', '便秘'],
#  ['消化不良', '便秘'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['心悸', '腹胀'],
#  ['脱发', '眼干', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '脱发', '眼干', '胸闷气短'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['腰疼', '脱发', '眼干'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '失眠', '月经不调'],
#  ['腰疼', '眼干', '便秘'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '失眠'],
#  ['消化不良', '腰疼', '脱发', '眼干', '易怒'],
#  ['失眠', '月经不调'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['心悸', '哮喘', '月经不调'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['失眠', '月经不调'],
#  ['失眠', '月经不调'],
#  ['神经衰弱', '失眠', '月经不调'],
#  ['眼干', '腰疼'],
#  ['消化不良', '便秘'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '眼干', '月经不调', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['脱发', '眼干', '月经不调'],
#  ['神经衰弱', '月经不调', '消化不良'],
#  ['消化不良', '易怒'],
#  ['哮喘', '胸闷气短'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['心悸', '失眠', '鼻炎', '耳鸣耳聋'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['神经衰弱', '失眠', '便秘'],
#  ['失眠', '哮喘', '鼻炎', '耳鸣耳聋'],
#  ['腰疼', '脱发', '眼干'],
#  ['哮喘', '腰疼'],
#  ['神经衰弱', '失眠', '便秘'],
#  ['失眠', '月经不调'],
#  ['胸闷气短', '耳鸣耳聋'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['消化不良', '月经不调'],
#  ['消化不良', '便秘'],
#  ['消化不良', '便秘'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['腰疼', '脱发', '眼干'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['消化不良', '腰疼', '脱发', '眼干', '易怒'],
#  ['腰疼', '脱发', '月经不调', '眼干'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['心悸', '失眠', '神经衰弱', '消化不良', '便秘'],
#  ['失眠', '眼干', '月经不调'],
#  ['消化不良', '易怒'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['失眠', '眼干', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '月经不调', '胸闷气短'],
#  ['失眠', '腰疼', '脱发', '眼干', '易怒'],
#  ['腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '鼻炎', '耳鸣耳聋'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱'],
#  ['神经衰弱', '月经不调', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠', '脱发', '眼干', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['失眠', '月经不调'],
#  ['胸闷气短', '耳鸣耳聋'],
#  ['心悸', '失眠'],
#  ['心悸', '失眠', '鼻炎', '耳鸣耳聋'],
#  ['失眠', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['哮喘', '鼻炎', '脱发'],
#  ['神经衰弱', '月经不调', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['哮喘', '鼻炎', '脱发'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '鼻炎', '耳鸣耳聋'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['消化不良', '腰疼', '脱发', '眼干', '易怒'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['消化不良', '便秘'],
#  ['心悸', '失眠', '眼干', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱'],
#  ['心悸', '腹胀'],
#  ['神经衰弱', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['心悸', '失眠'],
#  ['消化不良', '眼干'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '失眠'],
#  ['失眠', '月经不调'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['神经衰弱', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['心悸', '失眠'],
#  ['心悸', '失眠', '月经不调'],
#  ['消化不良', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['失眠', '哮喘', '鼻炎', '耳鸣耳聋'],
#  ['失眠', '哮喘', '鼻炎', '耳鸣耳聋'],
#  ['腹胀', '便秘'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['眼干', '腰疼'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['消化不良', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['脱发', '眼干', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['消化不良', '便秘'],
#  ['失眠', '腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '失眠', '月经不调', '胸闷气短'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['眼干', '腰疼'],
#  ['心悸', '失眠', '月经不调', '胸闷气短'],
#  ['腰疼', '脱发', '眼干'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['腰疼', '脱发', '眼干'],
#  ['失眠', '眼干', '月经不调'],
#  ['腰疼', '脱发', '眼干', '易怒'],
#  ['腰疼', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['消化不良', '眼干'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['腰疼', '眼干', '便秘'],
#  ['消化不良', '易怒'],
#  ['哮喘', '鼻炎', '脱发'],
#  ['眼干', '腰疼'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '鼻炎', '耳鸣耳聋'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['腰疼', '脱发', '眼干'],
#  ['消化不良', '便秘'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['哮喘', '鼻炎', '脱发'],
#  ['心悸', '失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['心悸', '哮喘', '月经不调'],
#  ['脱发', '眼干', '胸闷气短'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['哮喘', '胸闷气短'],
#  ['眼干', '腰疼'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['腰疼', '脱发', '眼干'],
#  ['神经衰弱', '眼干', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['失眠', '月经不调', '易怒'],
#  ['失眠', '月经不调'],
#  ['腹胀', '便秘', '消化不良'],
#  ['腹胀', '便秘'],
#  ['失眠', '腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '失眠', '鼻炎', '耳鸣耳聋'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['心悸', '月经不调', '胸闷气短'],
#  ['消化不良', '眼干'],
#  ['脱发', '眼干', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['消化不良', '腰疼', '脱发', '眼干', '易怒'],
#  ['消化不良', '月经不调'],
#  ['心悸', '失眠'],
#  ['消化不良', '易怒'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良'],
#  ['哮喘', '腰疼'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['眼干', '腰疼'],
#  ['消化不良', '腰疼', '脱发', '眼干', '易怒'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良', '鼻炎'],
#  ['神经衰弱', '眼干', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['心悸', '失眠'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['腰疼', '脱发', '月经不调', '眼干'],
#  ['腹胀', '便秘', '消化不良'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['腹胀', '便秘'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['消化不良', '腰疼', '脱发', '眼干', '易怒'],
#  ['心悸', '失眠', '月经不调'],
#  ['哮喘', '腰疼'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '失眠'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['脱发', '眼干'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠'],
#  ['失眠', '月经不调', '易怒'],
#  ['失眠', '眼干', '月经不调'],
#  ['消化不良', '眼干'],
#  ['失眠', '月经不调'],
#  ['消化不良', '便秘'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['脱发', '眼干', '月经不调'],
#  ['哮喘', '鼻炎', '脱发'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良'],
#  ['消化不良', '眼干'],
#  ['脱发', '眼干', '月经不调'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['心悸', '哮喘', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['脱发', '眼干', '月经不调'],
#  ['神经衰弱', '失眠', '月经不调'],
#  ['消化不良', '月经不调'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['失眠', '腰疼', '脱发', '眼干', '易怒'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠', '脱发', '眼干', '胸闷气短'],
#  ['心悸', '月经不调', '胸闷气短'],
#  ['腰疼', '眼干', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['腰疼', '脱发', '眼干', '易怒', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['消化不良', '便秘'],
#  ['心悸', '失眠', '脱发', '眼干', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['失眠', '眼干', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['胸闷气短', '耳鸣耳聋'],
#  ['心悸', '哮喘', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '眼干', '月经不调', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠'],
#  ['心悸', '月经不调', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['腰疼', '脱发', '眼干', '易怒', '月经不调'],
#  ['心悸', '失眠', '脱发', '眼干', '月经不调'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['脱发', '眼干', '胸闷气短'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['腰疼', '脱发', '眼干', '易怒', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['失眠', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['哮喘', '胸闷气短'],
#  ['消化不良', '便秘'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['心悸', '眼干', '易怒'],
#  ['失眠', '月经不调'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['消化不良', '便秘'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '月经不调'],
#  ['失眠', '哮喘', '鼻炎', '耳鸣耳聋'],
#  ['心悸', '神经衰弱'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '眼干', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['脱发', '眼干'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['消化不良', '便秘'],
#  ['失眠', '眼干', '月经不调'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '失眠', '月经不调'],
#  ['腹胀', '便秘', '哮喘', '胸闷气短', '消化不良'],
#  ['腰疼', '眼干', '月经不调'],
#  ['脱发', '眼干', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['腹胀', '便秘', '消化不良'],
#  ['心悸', '失眠'],
#  ['神经衰弱', '失眠', '便秘'],
#  ['失眠', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['心悸', '失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良', '鼻炎'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['心悸', '月经不调', '消化不良'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调', '消化不良'],
#  ['脱发', '眼干'],
#  ['神经衰弱', '眼干', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['消化不良', '眼干'],
#  ['心悸', '失眠', '月经不调'],
#  ['失眠', '月经不调'],
#  ['失眠', '月经不调'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['腰疼', '脱发', '眼干', '心悸'],
#  ['心悸', '神经衰弱', '眼干', '月经不调', '消化不良'],
#  ['心悸', '失眠', '腰疼', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['腰疼', '脱发', '月经不调', '眼干'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['神经衰弱', '眼干', '消化不良'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良', '便秘'],
#  ['神经衰弱', '消化不良'],
#  ['腹胀', '便秘'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['失眠', '眼干', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['腰疼', '脱发', '眼干'],
#  ['消化不良', '便秘'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['心悸', '神经衰弱', '消化不良'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['心悸', '神经衰弱', '眼干', '月经不调', '消化不良'],
#  ['失眠', '哮喘', '鼻炎', '耳鸣耳聋'],
#  ['眼干', '腰疼'],
#  ['失眠', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['失眠', '月经不调', '易怒'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['腰疼', '脱发', '眼干'],
#  ['心悸', '眼干', '易怒'],
#  ['失眠', '月经不调'],
#  ['心悸', '神经衰弱', '易怒', '消化不良'],
#  ['心悸', '失眠', '神经衰弱', '月经不调', '消化不良', '鼻炎'],
#  ['心悸', '失眠', '月经不调'],
#  ['心悸', '失眠', '腰疼', '眼干', '便秘'],
#  ['消化不良', '易怒'],
#  ['心悸', '失眠', '月经不调', '胸闷气短'],
#  ['心悸', '失眠', '眼干', '月经不调'],
#  ['心悸', '失眠', '鼻炎', '月经不调'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['消化不良', '眼干'],
#  ['腰疼', '脱发', '眼干'],
#  ['哮喘', '腰疼'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['脱发', '眼干', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['消化不良', '便秘'],
#  ['失眠', '眼干', '月经不调'],
#  ['腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['失眠', '月经不调', '易怒'],
#  ['心悸', '失眠', '月经不调', '胸闷气短'],
#  ['心悸', '哮喘', '月经不调'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['哮喘', '胸闷气短'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['神经衰弱', '消化不良', '月经不调'],
#  ['心悸', '神经衰弱'],
#  ['腹胀', '便秘'],
#  ['心悸', '失眠', '腰疼', '月经不调'],
#  ['失眠', '月经不调'],
#  ['心悸', '失眠', '月经不调'],
#  ['脱发', '眼干', '月经不调'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['失眠', '月经不调'],
#  ['消化不良', '便秘'],
#  ['心悸', '腹胀', '便秘', '消化不良'],
#  ['失眠', '月经不调'],
#  ['腰疼', '脱发', '月经不调', '眼干'],
#  ['神经衰弱', '消化不良', '便秘'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['神经衰弱', '月经不调', '消化不良'],
#  ['消化不良', '易怒'],
#  ['哮喘', '鼻炎', '脱发'],
#  ['心悸', '神经衰弱'],
#  ['脱发', '眼干'],
#  ['心悸', '失眠', '月经不调', '胸闷气短'],
#  ['哮喘', '胸闷气短'],
#  ['心悸', '失眠', '腰疼', '眼干', '便秘'],
#  ['腰疼', '脱发', '眼干'],
#  ['腰疼', '脱发', '月经不调', '眼干'],
#  ['失眠', '月经不调', '胸闷气短'],
#  ['心悸', '失眠', '鼻炎', '耳鸣耳聋'],
#  ['失眠', '哮喘', '鼻炎', '耳鸣耳聋'],
#  ['心悸', '眼干', '月经不调'],
#  ['腰疼', '脱发', '眼干', '易怒', '月经不调'],
#  ['心悸', '眼干', '月经不调', '鼻炎'],
#  ['脱发', '眼干', '月经不调'],
#  ['心悸', '哮喘', '月经不调']]

# %%
from mlxtend.preprocessing import TransactionEncoder

TE = TransactionEncoder()
data = TE.fit_transform(symptoms)

# %%
print(data)
# Out:
# [[ True False False ... False False False]
#  [False False  True ... False False False]
#  [False False False ...  True False False]
#  ...
#  [False False False ... False False  True]
#  [False False False ... False False False]
#  [False  True False ... False False False]]

# %%
df_sym = pd.DataFrame(data, columns=TE.columns_)

# %%
df_sym
# Out:
#         便秘     哮喘     失眠     心悸     易怒   月经不调   消化不良     眼干   神经衰弱   耳鸣耳聋  \
# 0     True  False  False  False  False  False   True  False  False  False
# 1    False  False   True   True  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False   True  False  False
# 3     True   True  False  False  False  False   True  False  False  False
# 4    False  False   True  False  False   True  False  False   True  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 995  False  False  False   True  False   True  False   True  False  False
# 996  False  False  False  False   True   True  False   True  False  False
# 997  False  False  False   True  False   True  False   True  False  False
# 998  False  False  False  False  False   True  False   True  False  False
# 999  False   True  False   True  False   True  False  False  False  False
#
#       胸闷气短     脱发     腰疼     腹胀     鼻炎
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False   True   True  False  False
# 3     True  False  False   True  False
# 4    False  False  False  False  False
# ..     ...    ...    ...    ...    ...
# 995  False  False  False  False  False
# 996  False   True   True  False  False
# 997  False  False  False  False   True
# 998  False   True  False  False  False
# 999  False  False  False  False  False
#
# [1000 rows x 15 columns]

# %%
from mlxtend.frequent_patterns import apriori

items = apriori(df_sym, min_support=0.1, use_colnames=True)

# %%
items.columns
# Out:
# Index(['support', 'itemsets'], dtype='object')

# %%
items_sorted = items.sort_values('support', axis = 0, ascending = False, inplace = False)
items_sorted
# Out:
#     support          itemsets
# 4     0.484            (月经不调)
# 3     0.452              (心悸)
# 2     0.393              (失眠)
# 5     0.344            (消化不良)
# 13    0.318        (失眠, 月经不调)
# 6     0.311              (眼干)
# 15    0.249        (心悸, 月经不调)
# 12    0.218          (失眠, 心悸)
# 7     0.188            (神经衰弱)
# 0     0.184              (便秘)
# 16    0.180        (心悸, 消化不良)
# 20    0.170        (眼干, 月经不调)
# 24    0.167    (失眠, 心悸, 月经不调)
# 21    0.164      (神经衰弱, 消化不良)
# 10    0.160              (腰疼)
# 11    0.160        (便秘, 消化不良)
# 9     0.151              (脱发)
# 22    0.143          (眼干, 脱发)
# 8     0.140            (胸闷气短)
# 23    0.136          (眼干, 腰疼)
# 1     0.124              (哮喘)
# 14    0.116          (失眠, 眼干)
# 17    0.114          (眼干, 心悸)
# 18    0.108        (神经衰弱, 心悸)
# 19    0.104      (消化不良, 月经不调)
# 25    0.100  (神经衰弱, 心悸, 消化不良)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(items, min_threshold=0.7)

# %%
rules
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0        (便秘)      (消化不良)               0.184               0.344    0.160
# 1        (失眠)      (月经不调)               0.393               0.484    0.318
# 2      (神经衰弱)      (消化不良)               0.188               0.344    0.164
# 3        (脱发)        (眼干)               0.151               0.311    0.143
# 4        (腰疼)        (眼干)               0.160               0.311    0.136
# 5    (失眠, 心悸)      (月经不调)               0.218               0.484    0.167
# 6  (神经衰弱, 心悸)      (消化不良)               0.108               0.344    0.100
#
#    confidence      lift  leverage  conviction
# 0    0.869565  2.527806  0.096704    5.029333
# 1    0.809160  1.671819  0.127788    2.703840
# 2    0.872340  2.535873  0.099328    5.138667
# 3    0.947020  3.045080  0.096039   13.004875
# 4    0.850000  2.733119  0.086240    4.593333
# 5    0.766055  1.582758  0.061488    2.205647
# 6    0.925926  2.691645  0.062848    8.856000

# %% [markdown]
# ### 说明
#
# * antecedents: 前件
#
# * consequents: 后件
#
# * lift：该关联规则的提升度
#
# $lift(\{A\} \rightarrow \{B\}) = \frac{support(\{A,B\})}{support(A)\times support(B)}$
#
# 值越大表明A和B的关联度越强
#
#
# * leverage： 关联规则的杠杆率
#
# $leverage(\{A\} \rightarrow \{B\}) = supper(\{A,B\}) - support(A) \times support(B) $
#
# 值越大表明A和B的关联度越强
#
# * conviction：关联规则的确信度
#
# $conv(\{A\} \rightarrow \{B\}) = \frac{1-support(B)}{1-conf(\{A\} \rightarrow \{B\})}$
#
# 值越大表明A和B的关联度越强

# %%
for i, j in rules.iterrows():
    X = j['antecedents']
    Y = j['consequents']
    x = ', '.join([item for item])
